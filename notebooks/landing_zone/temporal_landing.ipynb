# %% [markdown]
# # Landing Zone — Temporal
#
# This notebook handles the **raw data ingestion** step for the Landing Zone of our data pipeline.
# Its primary goal is to:
#
# 1. **Ingest raw data** from external sources
# 2. **Store the data** in MinIo being images and json documents

# %% [markdown]
# ## 1. Setup and Configuration

# %%
import os
from os.path import basename
import json
import requests
from dotenv import load_dotenv
from pathlib import Path, PurePosixPath
import hashlib
import mimetypes
import boto3
from botocore.config import Config
from boto3.s3.transfer import TransferConfig
from urllib.parse import urlparse
import ijson
from huggingface_hub import HfApi, hf_hub_url
from datasets import load_dataset


load_dotenv()

HF_TOKEN=os.getenv("HF_TOKEN")
HF_ORGA=os.getenv("HF_ORGA")
HF_DATASET=os.getenv("HF_DATASET")
HF_REV=os.getenv("HF_REV")
REPO_ID=f"{HF_ORGA}/{HF_DATASET}"

MINIO_USER=os.getenv("MINIO_USER")
MINIO_PASSWORD=os.getenv("MINIO_PASSWORD")
MINIO_ENDPOINT=os.getenv("MINIO_ENDPOINT")
MINIO_BUCKET = "landing-zone"
PREFIX = "temporal_landing"
TIMEOUT = 60

SKIP = {".gitattributes", ".gitignore", ".gitkeep"}


s3 = boto3.client(
    "s3",
    endpoint_url=MINIO_ENDPOINT,
    aws_access_key_id=MINIO_USER,
    aws_secret_access_key=MINIO_PASSWORD,
    region_name="us-east-1",
    config=Config(
        signature_version="s3v4",
        s3={"addressing_style": "path"}
    ),
)

transfer_cfg = TransferConfig(
    multipart_threshold=8 * 1024 * 1024,
    multipart_chunksize=8 * 1024 * 1024,
    max_concurrency=4,
    use_threads=True,
)

# %% [markdown]
# This block loads environment variables and sets up the connection to MinIO using **boto3**. It also defines basic constants like bucket name, prefixes, and timeouts used later in the process.

# %% [markdown]
# ## 2. Helper Functions

# %%
def make_minio_key(path: str) -> str:
    p = PurePosixPath(path)
    h = hashlib.sha256(str(p).encode("utf-8")).hexdigest()[:16]
    return f"{h}__{p.name or 'file'}"


def get_original_filename_from_key(key: str) -> str:
    name_part = Path(key).name
    if "__" in name_part:
        return name_part.split("__", 1)[1]
    return name_part


def upload_from_hf_url(hf_url: str, hf_token: str, original_path: str, *, revision=None, repo_id=None):
    headers = {"authorization": f"Bearer {hf_token}"} if hf_token else {}
    with requests.get(hf_url, stream=True, headers=headers, timeout=60) as r:
        r.raise_for_status()
        r.raw.decode_content = True

        key = f"temporal_landing/{make_minio_key(original_path)}"

        ctype, _ = mimetypes.guess_type(original_path)
        extra = {}
        if ctype:
            extra["ContentType"] = ctype

        meta = {
            "hf-original-path": original_path,
        }
        if revision:
            meta["hf-revision"] = str(revision)
        if repo_id:
            meta["hf-repo-id"] = str(repo_id)
        if meta:
            extra["Metadata"] = meta

        s3.upload_fileobj(
            Fileobj=r.raw,
            Bucket=MINIO_BUCKET,
            Key=key,
            Config=transfer_cfg,
            ExtraArgs=extra or None,
        )

    return f"s3://{MINIO_BUCKET}/{key}"


def _safe_ext_from_url(url: str) -> str:
    path = urlparse(url).path
    ext = PurePosixPath(path).suffix.lower().lstrip(".")
    if ext in {"jpg", "jpeg", "png", "gif", "webp", "bmp"}:
        return "jpg" if ext == "jpeg" else ext
    return ""


def _safe_ext_from_ctype(ctype: str | None) -> str:
    if not ctype:
        return ""
    ctype = ctype.split(";")[0].strip().lower()
    mapping = {
        "image/jpeg": "jpg",
        "image/png": "png",
        "image/gif": "gif",
        "image/webp": "webp",
        "image/bmp": "bmp",
    }
    return mapping.get(ctype, "")


def make_minio_key_image(recipe_id: str, index: int, ext: str, prefix: str = PREFIX) -> str:
    base_name = f"{recipe_id}_{index}.{ext or 'bin'}"
    h = hashlib.sha256(f"{recipe_id}:{index}".encode("utf-8")).hexdigest()[:32]
    return f"{prefix}/{h}__{base_name}"


def upload_image_from_url(url: str, recipe_id: str, index: int) -> str | None:
    headers = {}
    try:
        with requests.get(url, stream=True, timeout=TIMEOUT, headers=headers) as r:
            r.raise_for_status()
            r.raw.decode_content = True

            ext = _safe_ext_from_url(url)
            if not ext:
                ext = _safe_ext_from_ctype(r.headers.get("Content-Type")) or "jpg"
            ctype = r.headers.get("Content-Type") or mimetypes.guess_type(f"f.{ext}")[0]

            key = make_minio_key_image(recipe_id, index, ext)

            extra = {}
            if ctype:
                extra["ContentType"] = ctype
            extra["Metadata"] = {
                "source-url": url,
                "recipe-id": str(recipe_id),
                "image-index": str(index),
            }

            s3.upload_fileobj(
                Fileobj=r.raw,
                Bucket=MINIO_BUCKET,
                Key=key,
                Config=transfer_cfg,
                ExtraArgs=extra,
            )
            return f"s3://{MINIO_BUCKET}/{key}"

    except Exception as e:
        print(f"[WARN] Failure when uploading {url} (id={recipe_id}, idx={index}): {e}")
        return None
        
        
def process_layer2_images(repo_id: str, revision: str, hf_token: str | None, layer2_path: str):
    layer2_url = hf_hub_url(repo_id=repo_id, filename=layer2_path, repo_type="dataset", revision=revision)
    headers = {"authorization": f"Bearer {hf_token}"} if hf_token else {}

    print(f"[layer2] streaming from: {layer2_url}")
    with requests.get(layer2_url, stream=True, headers=headers, timeout=TIMEOUT) as r:
        r.raise_for_status()
        recipes = ijson.items(r.raw, "item")

        total_recipes = 0
        total_imgs = 0
        ok = 0
        for recipe in recipes:
            total_recipes += 1
            rid = str(recipe.get("id", "")).strip()
            images = recipe.get("images") or []
            for idx, img in enumerate(images):
                url = img.get("url")
                if not url:
                    continue
                total_imgs += 1
                if upload_image_from_url(url, rid, idx):
                    ok += 1
            
            if ok > 50 or total_recipes > 1000:
                break

        print(f"[layer2] recipes={total_recipes}, imgs={total_imgs}, uploaded_ok={ok}")

# %% [markdown]
# This block defines helper functions to generate file keys, manage uploads, and process image data. The naming convention for stored files follows a structured pattern like `type$dataset$timestamp$name.extension`. This model ensures that every object in MinIO is uniquely identifiable, traceable to its source, and easy to classify by type or dataset.
#
# The use of hashing and separators (`__` or `$`) keeps keys consistent and avoids collisions, while still preserving human-readable elements such as the original name or dataset reference. This approach provides both organization and scalability when handling large numbers of files.

# %% [markdown]
# ## 3. Ingest raw data from external source

# %%
api = HfApi()
files = api.list_repo_files(repo_id=REPO_ID, repo_type="dataset", revision=HF_REV)

for path in files:
    fname = basename(path)
    if fname.startswith(".") or fname.endswith(".tar") or fname in SKIP:
        continue
    
    print(fname)
    
    if fname == "layer2.json":
        process_layer2_images(REPO_ID, HF_REV, HF_TOKEN, path)  
    else:
        url=hf_hub_url(repo_id=REPO_ID, filename=path, repo_type="dataset", revision=HF_REV)
        dest_uri = upload_from_hf_url(
            hf_url=url,
            hf_token=HF_TOKEN,
            original_path=path,
            revision=HF_REV,
            repo_id=REPO_ID,
        )
        print("Uploaded at", dest_uri)
# Out:
# det_ingrs.json
# Uploaded at s3://landing-zone/temporal_landing/803760260afbeee8__det_ingrs.json
# layer1.json
# Uploaded at s3://landing-zone/temporal_landing/bdcc01219cf0d860__layer1.json
# layer2.json
# [layer2] streaming from: https://huggingface.co/datasets/ADSDB-DYS/adsdb-multimodal-food-data-management/resolve/main/recipe1M_layers/layer2.json
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_recipes/5806945844854784/0x0/photo.jpg (id=000075604a, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_recipes/5806945844854784/0x0/photo.jpg
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_recipes/5205549177110528/0x0/photo.jpg (id=00010379bf, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_recipes/5205549177110528/0x0/photo.jpg
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_photo_reports/4904504583520256/0x0/photo.jpg (id=00013266c9, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_photo_reports/4904504583520256/0x0/photo.jpg
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/182098-182099.jpg (id=00018371f2, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/182098-182099.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A5B6E0>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_photo_reports/6008901292523520/0x0/photo.jpg (id=00029f71f7, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_photo_reports/6008901292523520/0x0/photo.jpg
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_photo_reports/4743408963289088/0x0/photo.jpg (id=00029f71f7, idx=1): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_photo_reports/4743408963289088/0x0/photo.jpg
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/Popcorn-Trail-Mix-61178.jpg (id=0002a82634, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/Popcorn-Trail-Mix-61178.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A4B410>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_recipes/4558674072698880/0x0/photo.jpg (id=00033f624d, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_recipes/4558674072698880/0x0/photo.jpg
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/Mummy-Cupcakes-51857.jpg (id=00043c736b, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/Mummy-Cupcakes-51857.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A35910>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading http://images.media-allrecipes.com/userphotos/256x256/1036015.jpg (id=0004c7c040, idx=0): 403 Client Error: Forbidden for url: http://images.media-allrecipes.com/userphotos/256x256/1036015.jpg
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/opendeploy/169506_KRL_%20K8875V4EC_OR1_FO_640x428.jpg (id=0004d8bd26, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/opendeploy/169506_KRL_%20K8875V4EC_OR1_FO_640x428.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A34AD0>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading http://images.media-allrecipes.com/userphotos/256x256/709147.jpg (id=000507ca6b, idx=0): 403 Client Error: Forbidden for url: http://images.media-allrecipes.com/userphotos/256x256/709147.jpg
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/Caramelized-Beef-Skewers-53211.jpg (id=000590475e, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/Caramelized-Beef-Skewers-53211.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A49A30>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_recipes/b5c379058e834769/0x0/photo.jpg (id=0005a7b3b7, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_recipes/b5c379058e834769/0x0/photo.jpg
# [WARN] Failure when uploading http://images.media-allrecipes.com/userphotos/256x256/2202551.jpg (id=0005fc89f7, idx=0): 403 Client Error: Forbidden for url: http://images.media-allrecipes.com/userphotos/256x256/2202551.jpg
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/173076_ABO_67001v0_WP.jpg (id=0006ef8deb, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/173076_ABO_67001v0_WP.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A482F0>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/opendeploy/168183_640x428.jpg (id=000731b459, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/opendeploy/168183_640x428.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A37A10>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading http://assets.kraftfoods.com/recipe_images/opendeploy/51161_SGS_K15923V0_OR1_CR_640x428.jpg (id=00077e688b, idx=0): HTTPConnectionPool(host='assets.kraftfoods.com', port=80): Max retries exceeded with url: /recipe_images/opendeploy/51161_SGS_K15923V0_OR1_CR_640x428.jpg (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000272A3A5AEA0>: Failed to resolve 'assets.kraftfoods.com' ([Errno 11001] getaddrinfo failed)"))
# [WARN] Failure when uploading http://cdn-image.foodandwine.com/sites/default/files/200011-r-xl-cornmeal-crackers-with-pumpkin-seeds.jpg (id=0007f5f800, idx=0): 460 Client Error:  for url: http://cdn-image.foodandwine.com/sites/default/files/200011-r-xl-cornmeal-crackers-with-pumpkin-seeds.jpg
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_recipes/5372545340538880/0x0/photo.jpg (id=00081bb5ef, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_recipes/5372545340538880/0x0/photo.jpg
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_recipes/56399354/0x0/photo.jpg (id=000875a149, idx=0): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_recipes/56399354/0x0/photo.jpg
# [WARN] Failure when uploading https://img-global.cpcdn.com/001_photo_reports/5268399474081792/0x0/photo.jpg (id=000875a149, idx=1): 400 Client Error: Bad Request for url: https://img-global.cpcdn.com/001_photo_reports/5268399474081792/0x0/photo.jpg
# [WARN] Failure when uploading http://images.media-allrecipes.com/userphotos/256x256/950107.jpg (id=000875fa03, idx=0): 403 Client Error: Forbidden for url: http://images.media-allrecipes.com/userphotos/256x256/950107.jpg
# [WARN] Failure when uploading http://images.media-allrecipes.com/userphotos/256x256/2335645.jpg (id=000875fa03, idx=1): 403 Client Error: Forbidden for url: http://images.media-allrecipes.com/userphotos/256x256/2335645.jpg
# [WARN] Failure when uploading http://images.media-allrecipes.com/userphotos/256x256/1323244.jpg (id=000982e226, idx=0): 403 Client Error: Forbidden for url: http://images.media-allrecipes.com/userphotos/256x256/1323244.jpg
# [layer2] recipes=58, imgs=76, uploaded_ok=51
# recipes_with_nutritional_info.json
# Uploaded at s3://landing-zone/temporal_landing/a0ad8838a448b589__recipes_with_nutritional_info.json

# %% [markdown]
# This block lists all files from the Hugging Face dataset and uploads them to MinIO, skipping temporary or irrelevant files. For regular files, it generates the Hugging Face URL and uploads the content using the helper functions defined earlier.
#
# The file `layer2.json` is treated differently — it isn’t uploaded because it only contains metadata about images that are already extracted and stored separately. Instead, its content is processed directly to upload the referenced images, avoiding redundant storage.
